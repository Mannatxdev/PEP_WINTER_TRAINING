# %%
import pandas as pd 
import numpy as np 

data = pd.read_json('http://127.0.0.1:8000/api/users/?format=json')
data.head()
# Out:
#    id username password
# 0   1   Mannat    kumar
# 1   2    sunny    kumar
# 2   3      Raj    kumar
